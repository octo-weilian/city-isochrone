# %%
import osmnx as ox
import geopandas as gpd

# %%
city = ox.gdf_from_place('Wageningen,Gelderland,Nederland')

# %%
east,north,south,west=city.iloc[0][0],city.iloc[0][1],city.iloc[0][2],city.iloc[0][3]

# %%
g1=ox.graph_from_bbox(north,south,east,west,network_type='drive_service')

# %%
ox.plot_graph(g1)
# Out:
# (<Figure size 954.105x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x13a2ce9dd68>)

# %%
g2=ox.graph_from_place('Wageningen,Gelderland',network_type='drive_service')

# %%
ox.plot_graph(g2)
# Out:
# (<Figure size 825.45x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x13a2d77c4a8>)
